# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import svm
# %matplotlib inline

# %%
data = pd.read_csv('data_02.csv')
data.head()
# Out:
#    Weight  Height            Class
# 0    42.2      66        Dobermann
# 1    43.0      70        Dobermann
# 2    39.2      67        Dobermann
# 3    49.9      63       Rottweiler
# 4    39.5      65  German Shepherd

# %%
class_label = {'Dobermann':0, 'German Shepherd':1, 'Rottweiler':2}
data['Class_label'] = data['Class'].apply(lambda x: class_label[x])
data.head()
# Out:
#    Weight  Height            Class  Class_label
# 0    42.2      66        Dobermann            0
# 1    43.0      70        Dobermann            0
# 2    39.2      67        Dobermann            0
# 3    49.9      63       Rottweiler            2
# 4    39.5      65  German Shepherd            1

# %%
fig, ax = plt.subplots()
ax.scatter(x=data['Weight'], y = data['Height'], c = data['Class_label'])

# %%
model = svm.SVC(kernel = 'linear')
model.fit(data[['Weight', 'Height']], data['Class_label'])
# Out:
# SVC(kernel='linear')

# %%
X_test = np.random.rand(5000,2)
X_test = X_test*(40, 20) + (25, 55)

y_pred = model.predict(X_test)


fig, ax = plt.subplots()

ax.scatter(x=X_test[:,0], y=X_test[:,1], c=y_pred, alpha=.25)

colors = ['b', 'r', 'g']
x=data['Weight']
y=data['Height']
c=data['Class_label'].apply(lambda x: colors[x])
ax.scatter(x=x, y=y, c=c)
